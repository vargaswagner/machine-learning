# %% [markdown]
# <a href="https://colab.research.google.com/github/vargaswagner/machine-learning/blob/main/Hiperparametros.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
personas = pd.read_csv('/content/sample_data/ingresos.csv')
personas
# Out:
#     edad  estudio  genero  tipo_trabajo  horas  ingreso
# 0     27        9       0             0     40        0
# 1     30        9       0             0     40        0
# 2     34        8       0             0     40        0
# 3     26       13       0             0     50        0
# 4     23        4       1             0     25        0
# ..   ...      ...     ...           ...    ...      ...
# 95    32       13       1             0     55        1
# 96    20       10       0             0     25        0
# 97    46        3       0             0     40        0
# 98    37        9       1             0     45        0
# 99    47        9       1             0     12        0
#
# [100 rows x 6 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['index'].plot(kind='hist', bins=20, title='index')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['edad'].plot(kind='hist', bins=20, title='edad')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_2['estudio'].plot(kind='hist', bins=20, title='estudio')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_3['genero'].plot(kind='hist', bins=20, title='genero')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_4.plot(kind='scatter', x='index', y='edad', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_5.plot(kind='scatter', x='edad', y='estudio', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_6.plot(kind='scatter', x='estudio', y='genero', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_7.plot(kind='scatter', x='genero', y='tipo_trabajo', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['index']
#   ys = series['edad']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_8.sort_values('index', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('index')
# _ = plt.ylabel('edad')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['index']
#   ys = series['estudio']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_9.sort_values('index', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('index')
# _ = plt.ylabel('estudio')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['index']
#   ys = series['genero']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_10.sort_values('index', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('index')
# _ = plt.ylabel('genero')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['index']
#   ys = series['tipo_trabajo']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_11.sort_values('index', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('index')
# _ = plt.ylabel('tipo_trabajo')
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_12['index'].plot(kind='line', figsize=(8, 4), title='index')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_13['edad'].plot(kind='line', figsize=(8, 4), title='edad')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_14['estudio'].plot(kind='line', figsize=(8, 4), title='estudio')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_15['genero'].plot(kind='line', figsize=(8, 4), title='genero')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %%
from sklearn.ensemble import RandomForestClassifier

# Creamos el bosque
bosque = RandomForestClassifier()

# %%
# Visualizamos los hiperparámetros que podriamos utilizar
# Para este ejemplo utilizamos 2 o 3 hiperparámetros
bosque.get_params()
# Out:
# {'bootstrap': True,
#  'ccp_alpha': 0.0,
#  'class_weight': None,
#  'criterion': 'gini',
#  'max_depth': None,
#  'max_features': 'sqrt',
#  'max_leaf_nodes': None,
#  'max_samples': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'n_estimators': 100,
#  'n_jobs': None,
#  'oob_score': False,
#  'random_state': None,
#  'verbose': 0,
#  'warm_start': False}

# %%
# Creación de la rejilla (bosque) con validación cruzada
from sklearn.model_selection import GridSearchCV

# Creamos el diccionario de los hiperparámetros
hiperparametros = {
    "criterion": ("gini", "entropy"),
    "n_estimators": (10, 15, 20),
    "max_samples": (1/3, 2/3)
}

# Creamos la rejilla, le pasamos el bosque, los hiperparámetros y la métrica 'accuracy'
rejilla = GridSearchCV(bosque, hiperparametros, scoring="accuracy")

# %%
# Entrenamos el modelo
rejilla.fit(personas[personas.columns[:-1]].values, personas["ingreso"].values)
# Out:
# GridSearchCV(estimator=RandomForestClassifier(),
#              param_grid={'criterion': ('gini', 'entropy'),
#                          'max_samples': (0.3333333333333333,
#                                          0.6666666666666666),
#                          'n_estimators': (10, 15, 20)},
#              scoring='accuracy')

# %%
# Obtenemos información de la rejilla
sorted(rejilla.cv_results_.keys())
# Out:
# ['mean_fit_time',
#  'mean_score_time',
#  'mean_test_score',
#  'param_criterion',
#  'param_max_samples',
#  'param_n_estimators',
#  'params',
#  'rank_test_score',
#  'split0_test_score',
#  'split1_test_score',
#  'split2_test_score',
#  'split3_test_score',
#  'split4_test_score',
#  'std_fit_time',
#  'std_score_time',
#  'std_test_score']

# %%
# Prametros explorados
rejilla.cv_results_["params"]
# Out:
# [{'criterion': 'gini', 'max_samples': 0.3333333333333333, 'n_estimators': 10},
#  {'criterion': 'gini', 'max_samples': 0.3333333333333333, 'n_estimators': 15},
#  {'criterion': 'gini', 'max_samples': 0.3333333333333333, 'n_estimators': 20},
#  {'criterion': 'gini', 'max_samples': 0.6666666666666666, 'n_estimators': 10},
#  {'criterion': 'gini', 'max_samples': 0.6666666666666666, 'n_estimators': 15},
#  {'criterion': 'gini', 'max_samples': 0.6666666666666666, 'n_estimators': 20},
#  {'criterion': 'entropy',
#   'max_samples': 0.3333333333333333,
#   'n_estimators': 10},
#  {'criterion': 'entropy',
#   'max_samples': 0.3333333333333333,
#   'n_estimators': 15},
#  {'criterion': 'entropy',
#   'max_samples': 0.3333333333333333,
#   'n_estimators': 20},
#  {'criterion': 'entropy',
#   'max_samples': 0.6666666666666666,
#   'n_estimators': 10},
#  {'criterion': 'entropy',
#   'max_samples': 0.6666666666666666,
#   'n_estimators': 15},
#  {'criterion': 'entropy',
#   'max_samples': 0.6666666666666666,
#   'n_estimators': 20}]

# %%
# Resultados de la búsqueda
print(rejilla.cv_results_["rank_test_score"])
# Out:
# [ 9  2  9  3  4  6  6  1  6 11  4 12]

# %%
# Visualizamos el rendimiento de cada bosque
print(rejilla.cv_results_["mean_test_score"])
# Out:
# [0.78 0.83 0.78 0.81 0.8  0.79 0.79 0.84 0.79 0.76 0.8  0.75]

# %%
# Visualiazamos los mejores scores y los mejores parámetros
print(rejilla.best_score_)
print(rejilla.best_params_)
# Out:
# 0.8400000000000001
# {'criterion': 'entropy', 'max_samples': 0.3333333333333333, 'n_estimators': 15}

# %%
# Seleccionamos el bosque ganador
bosque_ganador = rejilla.best_estimator_
bosque_ganador
# Out:
# RandomForestClassifier(criterion='entropy', max_samples=0.3333333333333333,
#                        n_estimators=15)

# %%
# Realizamos un ejemplo de predicción
print(bosque_ganador.predict([[40, 10, 1, 0, 50]]))
# Out:
# [1]
